# %% [markdown]
# ## Movie Industry
#
# Dataset was obtained from Kaggle <https://www.kaggle.com/danielgrijalvas/movies> and uploaded by Daniel Grijalva.
#
# There are 6820 movies in the dataset (220 movies per year, 1986-2016). Each movie has the following attributes:
# 1. budget: the budget of a movie. Some movies don't have this, so it appears as 0
# 2. company: the production company
# 3. country: country of origin
# 4. director: the director
# 5. genre: main genre of the movie.
# 6. gross: revenue of the movie
# 7. name: name of the movie
# 8. rating: rating of the movie (R, PG, etc.)
# 9. released: release date (YYYY-MM-DD)
# 10. runtime: duration of the movie
# 11. score: IMDb user rating
# 12. votes: number of user votes
# 13. star: main actor/actress
# 14. writer: writer of the movie
# 15. year: year of release

# %% [markdown]
# ### Import the relevant Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %% [markdown]
# ### Load the data

# %%
df = pd.read_csv('movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# ### Data cleaning

# %% [markdown]
# #### Remove missing values

# %%
#Check for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100,5)))
# Out:
# name - 0.0%
# rating - 1.00417%
# genre - 0.0%
# year - 0.0%
# released - 0.02608%
# score - 0.03912%
# votes - 0.03912%
# director - 0.0%
# writer - 0.03912%
# star - 0.01304%
# country - 0.03912%
# budget - 28.31247%
# gross - 2.46479%
# company - 0.2217%
# runtime - 0.05216%

# %%
#Drop NULL values
new_df = df.dropna()

# %%
for col in new_df.columns:
    pct_missing = np.mean(new_df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100,5)))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %% [markdown]
# #### Check data types

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Change budget, gross and votes from float64 to int64.
new_df['budget'] = new_df['budget'].astype('int64')
new_df['gross'] = new_df['gross'].astype('int64')
new_df['votes'] = new_df['votes'].astype('int64')

# %%
new_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %% [markdown]
# #### Separate date of release and country of release from released column

# %%
new_df[['releasedate','releasecountry']] = new_df['released'].str.split('(', n=1, expand=True)
new_df['releasecountry'] = new_df['releasecountry'].str.replace(')', '')
new_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#Change release date format to datetime
new_df['releasedate'] = pd.to_datetime(new_df['releasedate'])

# %%
#Extract year from releasedate

new_df['releaseyear'] = pd.DatetimeIndex(new_df['releasedate']).year
new_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %% [markdown]
# #### Order data by gross revenue

# %%
pd.set_option('display.max_rows', None) #display all rows

# %%
new_df = new_df.sort_values(by=['gross'], inplace=False, ascending=False)
new_df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %% [markdown]
# ### Analysing variables

# %% [markdown]
# #### Correlation between Numeric variables

# %%
#Correlation between variables
df.corr(method='pearson') 
#Different types of corr: pearson (default), kendall, spearman correlation
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
corr_matrix = df.corr(method='pearson')

sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %% [markdown]
# Heat map shows that there is a high correlation between the budget of the film and the gross revenue generated.

# %% [markdown]
# #### Budget vs Gross

# %%
plt.scatter(new_df['budget'], new_df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget for Film')
plt.ylabel('Gross Revenue')
plt.ylim(bottom=0)
plt.show()

# %% [markdown]
# #### Plot Budget vs Gross Regression Line using Seaborn

# %%
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'red'}, line_kws={'color':'blue'})

# %% [markdown]
# #### Correlation between Numeric and Non-Numeric variables
#
# #### Assigning Dummy Variables

# %%
df_numeric = new_df.copy()
df_numeric.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
for col in df_numeric.columns:
    if df_numeric[col].dtype == 'object':
        df_numeric[col] = df_numeric[col].astype('category') #Change object to category
        df_numeric[col] = df_numeric[col].cat.codes
        
df_numeric.head()
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000       785    1263
# 7445   388       5      0  2019       137    8.4   903000       105     513
# 3045  4909       5      6  1997       534    7.8  1100000       785    1263
# 6663  3643       5      0  2015       529    7.8   876000       768    1806
# 7244   389       5      0  2018       145    8.4   897000       105     513
#
#       star  country     budget       gross  company  runtime releasedate  \
# 5445  1534       47  237000000  2847246203     1382    162.0  2009-12-18
# 7445  1470       47  356000000  2797501328      983    181.0  2019-04-26
# 3045  1073       47  200000000  2201647264     1382    194.0  1997-12-19
# 6663   356       47  245000000  2069521700      945    138.0  2015-12-18
# 7244  1470       47  321000000  2048359754      983    149.0  2018-04-27
#
#       releasecountry  releaseyear
# 5445              47         2009
# ...

# %%
df_numeric.corr()
# Out:
#                     name    rating     genre      year  released     score  \
# name            1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating         -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre           0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year            0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released       -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score           0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes           0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director        0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer          0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star           -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country        -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# ...

# %%
sns.heatmap(df_numeric.corr(), annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_numeric_unstacked = df_numeric.corr().unstack()
sorted_corr = df_numeric_unstacked.sort_values(ascending=False)
high_corr = sorted_corr[sorted_corr.between(0.5,1, inclusive=False)]
high_corr
# Out:
# releaseyear  year           0.998726
# year         releaseyear    0.998726
# budget       gross          0.740247
# gross        budget         0.740247
#              votes          0.614751
# votes        gross          0.614751
# dtype: float64

# %% [markdown]
# Higher budget of film may positively influence the quality of the film produced (e.g. better animation, effects, actors/actresses, etc) which will in turn generate higher gross revenue from better ticket sales.
#
# Also, as the number of viewers increase, the user votes and gross revenue will increase together as well.
